# %% [markdown]
# <a href="https://colab.research.google.com/github/AylinNaebzadeh/Complex-Dynamic-Network/blob/main/Assignment_4_Wiki_Vote.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
import pylab as plt
import statistics
from itertools import chain
from collections import Counter
from operator import itemgetter
import pickle
import json
from networkx.algorithms.community import quality

# %%
G = nx.read_edgelist("Wiki-Vote.txt", nodetype=int, create_using=nx.DiGraph(), comments='#')

# %% [markdown]
# Find Communities using Greedy algorithm

# %%
c = nx.community.greedy_modularity_communities(G)

print(c)
# Out:
# [frozenset({8192, 8193, 8194, 8195, 8196, 8197, 8198, 8199, 8202, 8203, 8204, 8205, 8206, 15, 8209, 8211, 8212, 8213, 8214, 8215, 8216, 8219, 8221, 8222, 8224, 8225, 8226, 8227, 8229, 8231, 8232, 8233, 8235, 8236, 8237, 8238, 8241, 8242, 8243, 8244, 8245, 53, 8246, 8248, 8249, 8251, 8252, 8253, 8254, 8255, 8256, 8260, 8261, 8262, 68, 8264, 8265, 8266, 8263, 8270, 8271, 8272, 8273, 8274, 8275, 8276, 8277, 99, 8294, 8295, 8296, 8297, 109, 122, 136, 155, 213, 222, 291, 335, 388, 395, 398, 434, 465, 525, 532, 580, 582, 608, 625, 690, 737, 766, 825, 827, 840, 850, 879, 896, 909, 938, 950, 967, 1004, 1008, 1024, 1041, 1060, 1063, 1074, 1132, 1133, 1157, 1159, 1179, 1191, 1239, 1307, 1310, 1359, 1365, 1385, 1401, 1403, 1493, 1498, 1509, 1539, 1542, 1548, 1550, 1554, 1612, 1647, 1667, 1680, 1688, 1706, 1722, 1733, 1748, 1762, 1775, 1777, 1789, 1796, 1799, 1807, 1813, 1823, 1865, 1874, 1879, 1912, 1915, 1924, 1935, 1937, 1946, 1947, 1961, 1971, 1972, 1982, 1984, 1990, 2001, 2003, 2010, 2011, 
# ...

# %% [markdown]
# Find the Modularity Value

# %%
modularity_value = quality.modularity(G, c)

print(modularity_value)
# Out:
# 0.3318771962441149
