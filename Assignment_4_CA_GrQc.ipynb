# %% [markdown]
# <a href="https://colab.research.google.com/github/AylinNaebzadeh/Complex-Dynamic-Network/blob/main/Assignment_4_CA_GrQc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
import statistics
from itertools import chain
from collections import Counter
from operator import itemgetter
import pickle
import json
from networkx.algorithms.community import quality

# %%
G = nx.read_edgelist("CA-GrQc.txt", nodetype=int, create_using=nx.DiGraph(), comments='#')
number_of_nodes = G.number_of_nodes()
number_of_edges = G.number_of_edges()
print(f"The number of nodes in the graph network is: {number_of_nodes}")
print(f"The number of edges in the graph network is: {number_of_edges}")
# Out:
# The number of nodes in the graph network is: 5242
# The number of edges in the graph network is: 28980

# %%
c = nx.community.greedy_modularity_communities(G)

print(c)
# Out:
# [frozenset({8193, 22530, 8198, 4102, 12296, 6154, 24587, 10251, 6156, 18445, 8206, 14351, 18447, 24592, 8211, 4117, 14357, 12311, 18457, 26, 8219, 8222, 16414, 8224, 14371, 20515, 20517, 24614, 8231, 4135, 14377, 16429, 20526, 6190, 12337, 20533, 20536, 18489, 20538, 62, 14403, 22598, 6219, 22603, 2127, 18511, 80, 12369, 22609, 16469, 18517, 12373, 16471, 16485, 12389, 2155, 18540, 16495, 8305, 16498, 4211, 18549, 6264, 2169, 16506, 122, 2182, 135, 10376, 16521, 141, 10381, 4242, 14485, 10391, 4249, 24731, 24734, 14497, 10406, 20647, 22696, 22699, 6317, 4273, 18612, 183, 4283, 20668, 16576, 22721, 22722, 195, 14534, 8391, 4298, 20683, 205, 4301, 22734, 6351, 8408, 14559, 22758, 6376, 6380, 22771, 2293, 22778, 10490, 12545, 16644, 260, 2309, 8452, 22791, 14599, 6408, 8458, 16649, 16659, 6421, 14615, 14619, 10524, 14621, 14627, 18724, 2341, 22826, 22830, 2352, 18736, 18739, 2356, 24885, 14647, 10552, 18745, 10555, 2368, 4416, 12611, 6468, 18757, 14661, 18758, 4422, 4428, 16719, 2388, 1
# ...

# %%
modularity_value = quality.modularity(G, c)

print(modularity_value)
# Out:
# 0.8198079658944767
